# %%
import copy
import csv
import os
import re
from external_functions import *

# %% [markdown]
# #### **Text Extraction**

# %%
uppercase_colon_pattern = re.compile("^(?P<speaker>([QA]\. BY )?(M[Rr]?[Ss]?\.? )?(A )?(([A-Z]{2,}[\- ]?)+)|(JUROR NO\. [0-9]+)):(\s)*") # Mr. Mesereau:, A Juror:, The Court:
uppercase_pattern = re.compile("^(M[Rr]?[Ss]?\.? )?((Mc|Le)?[A-Z]{2,}[\- ]?)+(([A-Z](\. |[’']))([A-Z]{2,}[\- ]?)*)?(, (JR|SR)\.)?(\([A-Za-z]+\))?$")
# Examples of patterns to be matched: DIRECT EXAMINATION, CROSS-EXAMINATION (Continued), SHAWN O'GRADY, CAROLE McCOY
# VICTOR M. ALVAREZ, PHILLIP LeMARQUE, HERIBERTO MARTINEZ, JR., ADRIAN MARIE McMANUS, JAMES F. VAN NORMAN, 

exception_pattern = re.compile("BY: *$|DATED: *$|APPEARANCES OF COUNSEL: *$")
qa_pattern = re.compile("(?P<qa>^[QA]\.)\s*")
proceedings_pattern = re.compile("^[\(]?The following proceedings were held")

def new_speaker_identifier(text, previous_status):
    """Helper function to read_from_file() identifying if a new line starts with a new speaker. If it does,\n
    the speaker name, the speaker text (i.e. the text line minus the speaker name) and status (reading, \n
    recess, reading_message or end_of_day) is returned."""
    
    # Checking for changes in status
    if previous_status == "not_started":
        if re.search("Santa Maria, California$", text):
            return ("Start of Day Message", text, "reading_message")
        else:
            return None
    elif previous_status == "reading":
        if re.search("Recess taken", text):
            return ("Recess Message", text, "recess")
        elif re.search("\(The proceedings adjourned[\S ]+\)", text):
            return ("Adjourn Message", text, "end_of_day")
    
    # Standard case: Finding matches like "MR. AUCHINCLOSS:"
    if previous_status in ["reading", "recess"]:
        groups = uppercase_colon_pattern.search(text) # Mr. Mesereau:, A Juror:, The Court:  
        if groups:
            if not exception_pattern.search(groups.group(0)):
                speaker = groups.group("speaker").replace("BY ", "").title() # Returns "The Court" for new_speaker_groups.group(0) = "THE COURT: "
                speaker_text = text.replace(groups.group(0), "") # Returns "Good morning." for "THE COURT: Good morning."
                return (speaker, speaker_text, "reading")
            else:
                return None
    
    # If previous_status == "reading", look for two additional types of matches
    if previous_status == "reading":
        
        # Finding matches, at the end of a line, like "MR. JESUS SALAS", "DIRECT EXAMINATION (Continued)" 
        groups = uppercase_pattern.search(text)
        if groups:
            speaker = groups.group(0).title()
            if len(speaker) >= 5:
                return ("Message", groups.group(0), "reading_message")
        
        # Finding matches for "Q. " and "A. "
        groups = qa_pattern.search(text)
        if groups:
            speaker = groups.group("qa")
            speaker_text = qa_pattern.sub("", text)
            return (speaker, speaker_text, "reading")
        
        groups = proceedings_pattern.search(text)
        if groups:
            return ("Message", text, "reading_message")

text_input = "A. This has the D.A. and then it has her. It"
new_speaker_identifier(text_input, "reading")
# Out:
# ('A.', 'This has the D.A. and then it has her. It', 'reading')

# %%
def create_speaking_segment(speaker, speaker_lines):
    """Returns a speaking segment (a dictionary with text and a speaker). Speaker_lines is a list of text items to be merged"""
    segment_text = re.sub("okay\. --$", "okay --.", " ".join(speaker_lines))
    if speaker in ["Message", "Recess Message", "Adjourn Message"]:
        segment_text = re.sub("[\(\)]", "", segment_text) # Removes any parenthesis around message text
    speaking_segment = {"text": segment_text, "speaker": speaker}
    return speaking_segment

# %%
# The named group main_content returns the text of each line, if any. For example,
# "7 THE PEOPLE OF THE STATE OF )" returns "THE PEOPLE OF THE STATE OF )" while "6" returns no match
content_pattern = re.compile("(\s*\d+\s+)(?P<main_content>[\S ]+)(\s)")
replacements = {
    re.compile("[ ]{2,}"): " ",
    re.compile("‘|’"): "'",
    re.compile("\.'"): "'.",
    re.compile(",'"): "',",
    re.compile("\/{2,}"): "",
    re.compile(" \. "): ". ",
    re.compile(" \.$"): ".",
    re.compile(" \? "): "? ",
    re.compile(" \?$"): "?",
    re.compile(" ,"): ",",
    re.compile(",\”"): "”,",
    re.compile(" ;"): ";",
    re.compile(" :"): ":",
    re.compile("Aja"): "Azja",
    re.compile("MR\. MR\."): "MR.",
    re.compile("MR "): "MR. ",
    re.compile("Mr "): "Mr. ",
    re.compile("MESSEREAU"): "MESEREAU",
    re.compile("Davallin"): "Davellin",
    re.compile("ANTHONY A\. CANTU"): "ANTONIO A. CANTU",
    re.compile("Robeson"): "Robson",    
    re.compile(" 's"): "'s",
    re.compile(" 't"): "'t",
    re.compile(" 'd"): "'d",
    re.compile(" 've"): "'ve",
    re.compile(" 're"): "'re",
    re.compile(" 'll"): "'ll",
    re.compile("“”"): "“",
    re.compile(" ”"): "”",
    re.compile("”\.”|\.”"): "”.",
    re.compile("”,”|,”"): "”,",
    re.compile(" \.”"): "”.",
    re.compile(" “\?"): "”?",
    re.compile(" \.\)"): ".)",
    re.compile("'\.s"): ".'s", # D.A'.s => D.A.'s
    re.compile("Lamir"): "LaMere"
    }

def extract_line_text(line):
    """Returns extracted text for a line of text. Returns None if no text can be extracted."""
    try:
        line_text = content_pattern.search(line).group("main_content")
        for regex, repl in replacements.items(): # Making replacements as needed
            line_text = regex.sub(repl, line_text)
        if re.search("^\s*28", line): # For lines of text starting with 28 (this represents the last line for each page):
            line_text = re.sub(" ?[0-9]+\s*$", "", line_text) # This removes the page numbering
        if line_text == "":
            return None
        else:
            return line_text
    except:
        return None

line = "18 BY MR. SNEDDON: "
extract_line_text(line)
# Out:
# 'BY MR. SNEDDON:'

# %%
def read_from_file(file):
    """Reading the information from a single text file, returning a list of speaking segments"""

    transcript = []
    speaker = None # Necessary in order not to read formalia at the beginning of each file
    status = "not_started"
    
    for line in file.readlines(): # Iterating over each file line by line

        # Extracting the text line by line if there is any text to be extracted 
        line_text = extract_line_text(line)
        if not line_text: # If there is no text to extract, continue to the next line of text
           continue
        
        # These lines of code makes sure that a message always corresponds to at least two lines of codes,
        # for example "DIRECT EXAMINATION (Continued)\n" followed by "BY MR. AUCHINCLOSS:""
        if status == "reading_message":
            status = "reading"
            if line_text[:2] == "BY":
                speaker_lines.append(line_text)
                continue

        # If line contains new speaker
        try:
            new_speaker, speaker_text, status = new_speaker_identifier(line_text, status)
            # If previous lines contained a speaker
            if speaker:
                # The dictionary speaking_segment is assigned the text of previous speaker.
                speaking_segment = create_speaking_segment(speaker, speaker_lines)
                transcript.append(speaking_segment)
            
            speaker_lines = [speaker_text] # Speaker_lines is recreated with the current speaker_text
            
            # Updating the speaker for next iteration, i.e. for the next line of text to be read
            speaker = new_speaker

            # The current line of text being read is added as a speaking segment, e.g. Recess Message: Recess taken
            if status in ["recess", "end_of_day"]:
                speaking_segment = create_speaking_segment(speaker, speaker_lines)
                transcript.append(speaking_segment)
                speaker = None
                if status == "end_of_day":
                    break # No need to do further iterations
        
        except:
            # If there is no speaker and line_text contains no speaker info, don't read the line
            if speaker is None:
                continue
            # If same speaker as previous line, simply append the current line of text to that speaker
            else:
                speaker_lines.append(line_text)
    
    return transcript

# %%
def iterating_over_files(specified_file = None):
    """Iterates over a single file or all files in the Transcripts directory, returning a dictionary\n
    transcripts where each value corresponds to a file (as processed by read_from_file())"""

    transcripts = {} # Dictionary to store all text and information that is read in
    directory_path = "Transcripts" # Name of folder containing all transcripts
    for file_name in os.listdir(directory_path):
        file_path = os.path.join(directory_path, file_name)

        # In case filename has been provided, non-matching file names are skipped
        if specified_file is not None: # If a filename has been provided
            if file_name != specified_file:
                continue
        
        if file_name == "Metadata.txt": # Don't read the metadata
            continue

        # For each file that is read
        with open(file_path, encoding="ansi") as file:#, encoding='utf-8', errors='replace') as file:
            transcript = read_from_file(file)
            transcripts[file_name.replace(".txt", "")] = transcript

    return transcripts

transcripts_v0 = iterating_over_files()#"2005-03-01".txt")
#transcripts_v0["2005-03-21"][:10]

# %%
def get_changed_speaker_names():
    """Returns a dictionary of the mapping of the speaker names that are to be changed as defined in changed_speaker_names.csv"""
    dictionary = {}
    with open("changed_speaker_names.csv") as csv_file:
        csv_reader = csv.DictReader(csv_file, delimiter=",")
        for row in csv_reader:
            original_name = row["original_name"]
            new_name = row ["new_name"]
            dictionary[original_name] = new_name
    return dictionary

changed_speaker_names = get_changed_speaker_names()

# %%
def get_read_back_offsets():
    """Returns a dictionary of lists using the data in read_back_offsets.csv. For example,\n
    we have '2005-03-04': ['-7', '-2'] as one of the entries on the returned dictionary. The\n
    interpretation of this is that for the court date 2005-03-04 the text corresponding to the\n
    first time "(Record read.)" appears is 7 seven speaking segments prior. The second time\n
    "(Record read.)" appears this difference is 2."""
    read_back_offsets = {}
    with open("read_back_offsets.csv") as csv_file:
        for row in csv_file:
            row_split = [x for x in row[:-1].split(",") if x != ""] # [:-1] removes \n at the end of each row
            court_date = row_split[0]
            offsets = row_split[1:]
            read_back_offsets[court_date] = offsets
        return read_back_offsets

# %%
def get_read_back_text(transcript, segment_number, court_date, record_reading):
    """Returns the text corresponing to each "(Record read.) in the transcripts,\n
    using the offsets specified in read_back_offsets.csv"""
    read_back_offsets = get_read_back_offsets()
    offsets = [int(offset) for offset in read_back_offsets[court_date][record_reading].split(";")]
    text_lst = []
    for offset in offsets:
        text_lst.append(transcript[segment_number + offset]["text"])
    text = " ".join(text_lst)
    return text

# %%
declared_sworn_pattern = re.compile("^(?P<name>[\S ]+[\S]*) (?P<text_after_name>Having (been (previously )?sworn|so affirmed)[\S ]+)")
examination_pattern = re.compile("(?P<examination_type>[\S ]*EXAMINATION (\(?[A-Za-z]+\)? )?BY) (?P<person_questioning>[\S ]+):$") # DIRECT EXAMINATION (Continued) BY MR. AUCHINCLOSS:
q_name_questioner_pattern = re.compile("^Q. (?P<questioner>[\S ]+)") # Example: "Q. BY MR. AUCHINCLOSS"
record_read_pattern = re.compile(" \(Record read\.\)")

def post_read_in_edits(transcripts):
    """After a first version of the "transcripts" dictionary has been created using "iterating_over_files()",\n
    this function iterates over all the speaking segments for all the court dates in "transcripts". This is \n 
    done in order to be able to explicitly specify all "Q." and "A." persons by name."""
    
    transcripts = copy.deepcopy(transcripts) # Necessary to preserve the old version of transcripts, transcripts_v0

    for court_date in transcripts.keys():
        
        transcript = transcripts[court_date]
        num_segments = len(transcript)
        segment_number = 0
        record_reading = 0 # Kepps track of the number of time (Record read.) appears in the text of each transcript

        while True:
            speaking_segment = transcript[segment_number]
            speaker = speaking_segment["speaker"]
            text = speaking_segment["text"]
            
            # Removing "(Record read.)"" from the text of speaking segments. Updating the value of record_read
            if record_read_pattern.search(text):
                text = record_read_pattern.sub("", text)
                speaking_segment["text"] = text
                record_read = True
            else:
                record_read = False

            # Captures "regular" messages as well as "Adjourn Message" and "Start of Day Message"
            if re.search("[Mm]essage", speaker):
                speaking_segment["type"] = "message"
                
                # Checking only regular messages
                if speaker == "Message":
                    # Checking for the name of the person being sworn in.
                    pattern_match = declared_sworn_pattern.search(text)
                    if pattern_match:
                        sworn_in_person = pattern_match.group("name").title().replace("Mcmanus", "McManus").replace("Mccoy", "McCoy").replace("Legrand", "LeGrand").replace("Lemarque", "LeMarque").replace("Mccullough", "McCullough")
                        #print(sworn_in_person)
                     # Retrieving new questioning persons for all spekaing segments containing "EXAMINATION BY xxx:"
                    else:
                        pattern_match = examination_pattern.search(text)
                        if pattern_match:
                            person_questioning = pattern_match.group("person_questioning").title()
            
            # Specifying the answering person for all answers
            elif speaker == "A.":
                speaking_segment["type"] = "answer"
                if sworn_in_person: # Should always evaluate to True
                    speaker = sworn_in_person
                    speaking_segment["speaker"] = speaker
                else:
                    print(text, "error") # Just making sure there are no errors
            
            # Specifying the questioning person for all questions
            elif speaker == "Q.":
                speaking_segment["type"] = "question"
                #speaking_segment["text"] = re.sub("(?<=[A-Za-z])\.$", "?", speaking_segment["text"]) # Adding question mark at the end of all questions
                if person_questioning: # Should always evaluate to True
                    speaker = person_questioning
                    speaking_segment["speaker"] =  person_questioning
                else:
                    print(text, "error") # Just making sure there are no errors

            # Handles speakers like "Q. BY MR. AUCHINCLOSS"
            elif q_name_questioner_pattern.search(speaker):
                speaker = q_name_questioner_pattern.search(speaker).group("questioner")
                speaking_segment["speaker"] = speaker
                speaking_segment["type"] = "question"

    
            else:
                speaking_segment["type"] = "normal"
                if speaker == "The Witness": # Should always evaluate to True
                    if sworn_in_person:
                        speaker = sworn_in_person
                        speaking_segment["speaker"] = speaker
                    else:
                        print(text, "error") # Just making sure there are no errors
            

            # Changing the speaker name for select speakers
            if speaker in changed_speaker_names:
                speaking_segment["speaker"] = changed_speaker_names[speaker]

            # Assigning the updated speaking segment to its court_date
            transcript[segment_number] = speaking_segment

            # If The Court Reporter reads from the record, an extra segment is inserted
            if record_read:
                text = get_read_back_text(transcript, segment_number, court_date, record_reading)
                record_reading += 1
                if text: # Given how the transcriptes are formatted, this if-condition is not really necessary
                    speaking_segment = {
                        "text": text,
                        "speaker": "The Court Reporter",
                        "type": "read-back"
                        }
                    segment_number = segment_number + 1
                    num_segments = num_segments + 1
                    transcript.insert(segment_number, speaking_segment)

            segment_number += 1
            if segment_number == num_segments: # True when there are no more segments to be read
                break
        
        transcripts[court_date] = transcript

    return transcripts

transcripts = post_read_in_edits(transcripts_v0)
#transcripts["2005-03-21"][:10]

# %%
def transcripts_to_files(transcripts, prefix = False):
    """Writes formatted court transcript to the folder "formatted-transcripts.txt"."""
    folder = "Formatted Transcripts"
    for court_date in transcripts.keys():
        short_date = "-".join(court_date.split("-")[1:]) # Example: Extracts "02-28" from "2005-02-28"
        path = os.path.join(folder, short_date + ".txt")
        with open(path, "w", encoding="utf-8") as file:
            for speaking_segment in transcripts[court_date]:
                speaker = speaking_segment["speaker"]
                text = speaking_segment["text"]
                
                if prefix == True:
                    segment_type = speaking_segment["type"]
                    if segment_type == "question":
                        prefix = "Q. "
                    elif segment_type == "answer":
                        prefix = "A. "
                    else:
                        prefix = ""
                else:
                    prefix = ""
            
                file.write(f"""{prefix}{speaker}: {text}\n""")

transcripts_to_files(transcripts, prefix=False)

# %% [markdown]
# #### **Output Validation**

# %%
def speakers(specified_court_date = None, sort_by="values"):
    """Returns a dictionary mapping each distinct speakers by number of speaking segments. By default,\n
    the returned dictionary is sorted by values in descending order, but if any other string value is\n
    passed in as the first argument alphabetical sorting is applied. The second argument, "specified_court_date",\n
    (which is also optional) makes it possible to only consider a specific court date."""
    
    all_speakers = {}
    for court_date in transcripts.keys():
        if specified_court_date is not None and court_date != specified_court_date:
            continue
        for speaking_segment in transcripts[court_date]:
            speaker = speaking_segment["speaker"]
            if speaker in all_speakers:
                all_speakers[speaker] += 1
            else:
                all_speakers[speaker] = 1
    
    if all_speakers == {}:
        print(f"""Typo error. Couldn't retrieve speakers for "{specified_court_date}".""")
    elif sort_by == "values": # Sorting be values (descending), then name
        return {k: v for k, v in sorted(all_speakers.items(), key=lambda item: (-item[1], item[0]))}
    else: # Sorting be keys (speaker names), alphabetical/ascending
        return {k: v for k, v in sorted(all_speakers.items(), key=lambda item: item[0])}
    return all_speakers

court_date = "2005-05-26"
speaker_dict = speakers(specified_court_date = None, sort_by="values")
for key, value in speaker_dict.items():
    print(f"{key}: {value}")
# Out:
# Mr. Mesereau: 30035
# Mr. Zonen: 13683
# Mr. Sneddon: 13088
# Mr. Sanger: 12908
# The Court: 10345
# Mr. Auchincloss: 8966
# Janet Arvizo: 5629
# Gavin Arvizo: 3302
# Star Arvizo: 3120
# Davellin Arvizo: 3031
# Mr. Nicola: 2814
# Rudy Provencio: 1736
# Craig Bonner: 1644
# Blanca Francia: 1519
# Hamid Moslehi: 1415
# Jesus Salas: 1342
# Ann Kite: 1340
# Brian Barron: 1289
# Adrian McManus: 1162
# June Chandler: 1140
# David LeGrand: 1127
# Mark Geragos: 1090
# Joseph Marcus: 1085
# Jay Jackson: 1056
# Jason Francia: 990
# Violet Silva: 946
# Azja Pryor: 900
# Kiki Fournier: 897
# Message: 872
# Irene Peters: 871
# Ralph Chacon: 855
# Steve Robel: 843
# Chris Tucker: 807
# Robert Spinner: 787
# Louise Palanker: 762
# Jamie Masada: 761
# Cynthia Montgomery: 677
# Debbie Rowe: 673
# Christian Robinson: 660
# William Dickerman: 627
# Joy Robson: 600
# Kassim Abdool: 594
# Paul Zelis: 583
# Larry Feldman: 579
# Lisa Hemman: 567
# Wade Robson: 564
# Jeff Klapakis: 535
# Victor Alvarez: 532
# Cynthia Ann Bell: 520
# Conn Abel: 511
# George Lopez: 443
# Stan Katz: 443
# Duross O'Bryan: 428
# Karen Walker: 409
# Rijo Jackson: 403
# Timothy Sutcliffe: 402
# Lisbeth Barnes: 400
# Macaulay Culkin: 393
# The Clerk: 378
# Phillip LeMarque: 368
# James Van Norman: 366
# Anthony Urquiza: 353
# Simone Jackson: 336
# Mercy Manrriquez: 330
# Albert Lafferty: 315
# Andrew Dietz: 314
# Maria Gomez: 314
# Ann Lopez: 311
# Laurence Nimmer: 307
# Brett Barnes: 306
# Michael Davy: 301
# Angel Vivanco: 284
# Antonio Cantu: 280
# Mary Holzer: 278
# Chantal Robson: 277
# Shane Meridith: 271
# Freddy Padilla: 267
# Kathryn Bernerd: 265
# Jack Green: 259
# Connie Keenan: 245
# Janet Williams: 245
# Bob Jones: 240
# Fritz Coleman: 235
# Terry Flaa: 223
# The Bailiff: 219
# Phillip Esplin: 218
# Mike Radakovich: 209
# Karen Shepherd: 198
# Dwayne Swingler: 188
# Julio Avila: 188
# Recess Message: 179
# George Erwin: 178
# Martin Bashir: 174
# Harry Koons: 163
# Karlee Barnes: 163
# Lauren Wallace: 162
# Jean Seamount: 159
# Alicia Romero: 153
# Vernee Watson Johnson: 140
# The Court Reporter: 137
# David Saunders: 135
# Maria Ventura: 135
# Jeffrey Schwartz: 130
# Russel Birchim: 130
# Stacy Brown: 127
# Robert Cooley: 126
# Jay Leno: 124
# Anne Marie Sims: 118
# Kris Kallman: 115
# Gayle Goforth: 109
# Bailiff Cortez: 108
# Gina Villegas: 102
# Monica Wakefield: 102
# Rosibel Smith: 102
# Ruby Wolff: 102
# Timothy Rooney: 101
# Nancy Torres: 99
# Lessie Wraggs: 98
# Tiffany Haynes: 94
# William Caldwell: 92
# Gabriel Dominguez: 91
# James Wittenbrock: 89
# Donna Aggers: 86
# Marian Arvizo: 82
# Ian Drew: 79
# Michelle Shelley: 79
# Ramon Velasco: 78
# Steven Moeller: 78
# Terry Paulsen: 78
# Carole McCoy: 77
# Mr. Boutrous: 77
# Ms. Sager: 76
# Beverly Wagner: 75
# Charlene Marie: 69
# Joseph Shebroe: 66
# The Jury: 66
# Adjourn Message: 65
# Start of Day Message: 65
# Francin Contreras: 64
# Michelle Jackson: 63
# Crystalee Danko: 62
# Brian Salce: 61
# Rod Forney: 59
# Stephen Cleaves: 55
# Arlene Kennedy: 52
# Karen Brando: 52
# Counsel At Counsel Table: 51
# Jeanne Mulcahy: 51
# Prudence Brando: 50
# Michael Viner: 49
# Christine Causer: 46
# Heriberto Martinez, Jr.: 43
# Suli McCullough: 42
# Theresa Marquez: 42
# Iris Finsilver: 41
# Jeffery Ellis: 41
# Jennifer Simmons: 41
# Anthony Ranieri: 40
# Carlos Velasco: 39
# Larry King: 38
# Joe Corral: 37
# Mr. Franklin: 34
# Shawn O'Grady: 32
# Mr. Moore: 31
# Ms. Yu: 28
# Mr. Levine: 26
# Mr. Beebe: 25
# The Reporter: 15
# Mr. Oxman: 14
# A Juror: 13
# The Defendant: 10
# The Interpreter: 8
# A Voice From The Audience: 7
# Mr. Kopp: 7
# Ms. Splitgerber: 7
# Mr. Blum: 6
# Mr. Dunkle: 6
# Bailiff Narron: 4
# Mr. Sanborn: 4
# Mr. Segal: 4
# Juror No. 7: 2
# Juror No. 8: 2
# Mr. Hoberman: 2
# Mr. Hunter: 2
# A Voice: 1
# An Alternate Juror: 1
# Bailiff Avila: 1
# Commander Meyer: 1
# Juror No. 4: 1
# Juror No. 5: 1
# Mr. Fields: 1
# The Sound Technician: 1
# The Technician: 1

# %%
# Prints all speakers without audio profiles
audio_profiles = get_audio_profiles()
for speaker, segment_count in speaker_dict.items():
    if speaker not in audio_profiles.keys() and not re.search("[Mm]essage", speaker):
        print(f"{speaker}: {segment_count}")

# %%
with open("speakers_without_pictures.csv") as file:
    csv_reader = csv.reader(file)
    speakers_without_pictures = [line[0] for line in csv_reader]

# Printing all speakers without images
for speaker in speaker_dict:
    image_path = os.path.join("pictures", speaker + ".jpg")
    if not os.path.isfile(image_path) and speaker not in speakers_without_pictures and not re.search("[Mm]essage", speaker):
        print(speaker)

# %%
# Printing speakers in speakers_without_pictures with pictures
for speaker in speakers_without_pictures:
    image_path = os.path.join("pictures", speaker + ".jpg")
    if os.path.isfile(image_path) or speaker not in speaker_dict:
        print(speaker)
    if speaker not in speaker_dict:
        print(speaker)

# %%
for speaker in os.listdir("pictures"):
    speaker = speaker[:-4]
    if speaker not in speaker_dict or speaker in speakers_without_pictures:
        print(speaker)
# Out:
# Janet Arvizo2

# %%
messages = set()

for transcript in transcripts.values():
    for speaking_segment in transcript:
        if speaking_segment["type"] == "message":
            messages.add(speaking_segment["text"])

messages
# Out:
# {'ADRIAN MARIE McMANUS Having been previously sworn, resumed the stand and testified further as follows:',
#  'ADRIAN MARIE McMANUS Having been sworn, testified as follows:',
#  'ALBERT LAFFERTY Having been previously sworn, resumed the stand and testified further as follows:',
#  'ALBERT LAFFERTY Having been sworn, testified as follows:',
#  'ALICIA ROMERO Having been previously sworn, resumed the stand and testified further as follows:',
#  'ALICIA ROMERO Having been sworn, testified as follows:',
#  'ANDREW R. DIETZ Having been sworn, testified as follows:',
#  'ANGEL VIVANCO Having been previously sworn, resumed the stand and testified further as follows:',
#  'ANGEL VIVANCO Having been sworn, testified as follows:',
#  'ANN KITE Having been sworn, testified as follows:',
#  'ANN MARIE KITE Having been previously sworn, resumed the stand and testified further as follows:',
#  'ANN SERRANO LOPEZ Having been sworn, testified as follows:',
#  'ANNE MARIE SIMS Having been sworn, testified as follows:',
#  'ANTHONY JOSEPH URQUIZA Having been sworn, testified as follows:',
#  'ANTHONY RANIERI Having been sworn, testified as follows:',
#  'ANTONIO A. CANTU Having been previously sworn, resumed the stand and testified further as follows:',
#  'ANTONIO A. CANTU Having been sworn, testified as follows:',
#  'ARLENE KENNEDY Having been sworn, testified as follows:',
#  'AZJA PRYOR Having been sworn, testified as follows:',
#  'BEVERLY WAGNER Having been sworn, testified as follows:',
#  'BLANCA FRANCIA Having been sworn, testified as follows:',
#  'BOB JONES Having been sworn, testified as follows:',
#  'BRETT CHRISTOPHER BARNES Having been sworn, testified as follows:',
#  'BRIAN BARRON Having been previously sworn, resumed the stand and testified further as follows:',
#  'BRIAN BARRON Having been sworn, testified as follows:',
#  'BRIAN SALCE Having been sworn, testified as follows:',
#  'CARLOS VELASCO Having been sworn, testified as follows:',
#  'CAROLE McCOY Having been sworn, testified as follows:',
#  'CHANTAL ROBSON Having been sworn, testified as follows:',
#  'CHARLENE MARIE Having been sworn, testified as follows:',
#  'CHRIS TUCKER Having been previously sworn, resumed the stand and testified further as follows:',
#  'CHRIS TUCKER Having been sworn, testified as follows:',
#  'CHRISTIAN ROBINSON Having been sworn, testified as follows:',
#  'CHRISTINE CAUSER Having been sworn, testified as follows:',
#  'CONN ABEL Having been previously sworn, resumed the stand and testified further as follows:',
#  'CONN ABEL Having been sworn, testified as follows:',
#  'CONNIE KEENAN Having been sworn, testified as follows:',
#  'CRAIG BONNER Having been previously sworn, resumed the stand and testified further as follows:',
#  'CRAIG BONNER Having been sworn, testified as follows:',
#  'CROSS-EXAMINATION BY MR. AUCHINCLOSS:',
#  'CROSS-EXAMINATION BY MR. MESEREAU:',
#  'CROSS-EXAMINATION BY MR. SANGER:',
#  'CROSS-EXAMINATION BY MR. SNEDDON:',
#  'CROSS-EXAMINATION BY MR. ZONEN:',
#  'CROSS-EXAMINATION Continued',
#  'CROSS-EXAMINATION Continued BY MR. AUCHINCLOSS:',
#  'CROSS-EXAMINATION Continued BY MR. MESEREAU:',
#  'CROSS-EXAMINATION Continued BY MR. SANGER:',
#  'CROSS-EXAMINATION Continued BY MR. SNEDDON:',
#  'CROSS-EXAMINATION Continued BY MR. ZONEN:',
#  'CRYSTALEE DANKO Having been sworn, testified as follows:',
#  'CYNTHIA ANN BELL Having been sworn, testified as follows:',
#  'CYNTHIA C. MONTGOMERY Having been sworn, testified as follows:',
#  'DAVELLIN ARVIZO Having been previously sworn, resumed the stand and testified further as follows:',
#  'DAVELLIN ARVIZO Having been sworn, testified as follows:',
#  'DAVID G. LEGRAND Having been previously sworn, resumed the stand and testified further as follows:',
#  'DAVID G. LEGRAND Having been sworn, testified as follows:',
#  'DAVID SAUNDERS Having been sworn, testified as follows:',
#  'DEBORAH ROWE JACKSON Having been sworn, testified as follows:',
#  'DIRECT EXAMINATION BY MR. AUCHINCLOSS:',
#  'DIRECT EXAMINATION BY MR. MESEREAU:',
#  'DIRECT EXAMINATION BY MR. NICOLA:',
#  'DIRECT EXAMINATION BY MR. SANGER:',
#  'DIRECT EXAMINATION BY MR. SNEDDON:',
#  'DIRECT EXAMINATION BY MR. ZONEN:',
#  'DIRECT EXAMINATION Continued BY MR. AUCHINCLOSS:',
#  'DIRECT EXAMINATION Continued BY MR. MESEREAU:',
#  'DIRECT EXAMINATION Continued BY MR. SANGER:',
#  'DIRECT EXAMINATION Continued BY MR. SNEDDON:',
#  'DIRECT EXAMINATION Continued BY MR. ZONEN:',
#  'DIRECT EXAMINATION Reopened BY MR. NICOLA:',
#  'DIRECT EXAMINATION Resumed BY MR. ZONEN:',
#  'DONNA AGGERS Having been sworn, testified as follows:',
#  'DWAYNE SWINGLER Having been sworn, testified as follows:',
#  'EXAMINATION BY THE COURT:',
#  'FRANCIN CONTRERAS Having been sworn, testified as follows:',
#  'FREDDY PADILLA Having been sworn, testified as follows:',
#  'FRITZ COLEMAN Having been sworn, testified as follows:',
#  'FURTHER CROSS-EXAMINATION BY MR. MESEREAU:',
#  'FURTHER DIRECT EXAMINATION BY MR. SNEDDON:',
#  'FURTHER RECROSS-EXAMINATION BY MR. AUCHINCLOSS:',
#  'FURTHER RECROSS-EXAMINATION BY MR. MESEREAU:',
#  'FURTHER RECROSS-EXAMINATION BY MR. SANGER:',
#  'FURTHER RECROSS-EXAMINATION BY MR. ZONEN:',
#  'FURTHER REDIRECT EXAMINATION BY MR. AUCHINCLOSS:',
#  'FURTHER REDIRECT EXAMINATION BY MR. MESEREAU:',
#  'FURTHER REDIRECT EXAMINATION BY MR. NICOLA:',
#  'FURTHER REDIRECT EXAMINATION BY MR. SANGER:',
#  'FURTHER REDIRECT EXAMINATION BY MR. SNEDDON:',
#  'FURTHER REDIRECT EXAMINATION BY MR. ZONEN:',
#  'GABRIEL DOMINGUEZ Having been sworn, testified as follows:',
#  'GAVIN-ANTON ARVIZO Having been previously sworn, resumed the stand and testified as follows:',
#  'GAVIN-ANTON ARVIZO Having been previously sworn, resumed the stand and testified further as follows:',
#  'GAVIN-ANTON ARVIZO Having been sworn, testified as follows:',
#  'GAYLE GOFORTH Having been sworn, testified as follows:',
#  'GEORGE ERWIN Having been sworn, testified as follows:',
#  'GEORGE LOPEZ Having been sworn, testified as follows:',
#  'GINA VILLEGAS Having been sworn, testified as follows:',
#  'HAMID MOSLEHI Having been previously sworn, resumed the stand and testified further as follows:',
#  'HAMID MOSLEHI Having been sworn, testified as follows:',
#  'HARRY KOONS Having been sworn, testified as follows:',
#  'HERIBERTO MARTINEZ, JR. Having been sworn, testified as follows:',
#  'IAN DREW Having been sworn, testified as follows:',
#  'IRENE LAVERN PETERS Having been sworn, testified as follows:',
#  'IRIS JOAN FINSILVER Having been sworn, testified as follows:',
#  'JACK GREEN Having been sworn, testified as follows:',
#  'JAMES F. VAN NORMAN Having been sworn, testified as follows:',
#  'JAMES WITTENBROCK Having been sworn, testified as follows:',
#  'JAMIE MASADA Having been sworn, testified as follows:',
#  'JANET JACKSON Having been previously sworn, resumed the stand and testified further as follows:',
#  'JANET JACKSON Having been sworn, testified as follows:',
#  'JANET WILLIAMS Having been sworn, testified as follows:',
#  'JASON FRANCIA Having been previously sworn, resumed the stand and testified further as follows:',
#  'JASON FRANCIA Having been sworn, testified as follows:',
#  'JAY D. JACKSON Having been previously sworn, resumed the stand and testified further as follows:',
#  'JAY D. JACKSON Having been sworn, testified as follows:',
#  'JAY LENO Having been sworn, testified as follows:',
#  'JEAN LORRAINE SEAMOUNT Having been sworn, testified as follows:',
#  'JEANNE MULCAHY Having been sworn, testified as follows:',
#  'JEFF KLAPAKIS Having been previously sworn, resumed the stand and testified further as follows:',
#  'JEFF KLAPAKIS Having been sworn, testified as follows:',
#  'JEFFERY ELLIS Having been sworn, testified as follows:',
#  'JEFFREY SCHWARTZ Having been sworn, testified as follows:',
#  'JENNIFER SIMMONS Having been sworn, testified as follows:',
#  'JESUS SALAS Having been previously sworn, resumed the stand and testified further as follows:',
#  'JESUS SALAS Having been sworn, testified as follows:',
#  'JOE J. CORRAL, JR. Having been sworn, testified as follows:',
#  "JOHN DUROSS O'BRYAN Having been sworn, testified as follows:",
#  'JOSEPH MARCUS Having been previously sworn, resumed the stand and testified further as follows:',
#  'JOSEPH MARCUS Having been sworn, testified as follows:',
#  'JOSEPH SHEBROE Having been sworn, testified as follows:',
#  'JOY ROBSON Having been sworn, testified as follows:',
#  'JULIO AVILA Having been sworn, testified as follows:',
#  'JUNE CHANDLER Having been sworn, testified as follows:',
#  'KAREN BRANDO Having been sworn, testified as follows:',
#  'KAREN SHEPHERD Having been sworn, testified as follows:',
#  'KAREN WALKER Having been sworn, testified as follows:',
#  'KARLEE BARNES Having been sworn, testified as follows:',
#  'KASSIM ABDOOL Having been sworn, testified as follows:',
#  'KATHRYN BERNERD Having been sworn, testified as follows:',
#  'KIKI FOURNIER Having been sworn, testified as follows:',
#  'KRIS KALLMAN Having been sworn, testified as follows:',
#  'LARRY FELDMAN Having been sworn, testified as follows:',
#  'LARRY KING Having been sworn, testified as follows:',
#  'LAUREN WALLACE Having been sworn, testified as follows:',
#  'LAURENCE NIMMER Having been previously sworn, resumed the stand and testified further as follows:',
#  'LAURENCE NIMMER Having been sworn, testified as follows:',
#  'LESSIE DEAN WRAGGS Having been sworn, testified as follows:',
#  'LISA SUSAN ROOTE HEMMAN Having been sworn, testified as follows:',
#  'LOUISE PALANKER Having been previously sworn, resumed the stand and testified further as follows:',
#  'LOUISE PALANKER Having been sworn, testified as follows:',
#  'MACAULAY CULKIN Having been sworn, testified as follows:',
#  'MARIA A. VENTURA Having been sworn, testified as follows:',
#  'MARIA GOMEZ Having been previously sworn, resumed the stand and testified further as follows:',
#  'MARIA GOMEZ Having been sworn, testified as follows:',
#  'MARIA VENTURA Having been previously sworn, resumed the stand and testified further as follows:',
#  'MARIAN ARVIZO Having been sworn, testified as follows:',
#  'MARIE LISBETH BARNES Having been sworn, testified as follows:',
#  'MARK GERAGOS Having been previously sworn, resumed the stand and testified further as follows:',
#  'MARK GERAGOS Having been sworn, testified as follows:',
#  'MARTIN BASHIR Having been sworn, testified as follows:',
#  'MARY ELIZABETH HOLZER Having been sworn, testified as follows:',
#  'MERCY DEE MANRRIQUEZ Having been sworn, testified as follows:',
#  'MICHAEL DAVY Having been sworn, testified as follows:',
#  'MICHAEL VINER Having been sworn, testified as follows:',
#  'MICHELLE HENRIETTE JACKSON Having been sworn, testified as follows:',
#  'MICHELLE SHELLEY Having been sworn, testified as follows:',
#  'MIKE RADAKOVICH Having been sworn, testified as follows:',
#  'MONICA DE LA SANTOS WAKEFIELD Having been sworn, testified as follows:',
#  'NANCY DIANA TORRES Having been sworn, testified as follows:',
#  'PAUL ZELIS Having been previously sworn, resumed the stand and testified further as follows:',
#  'PAUL ZELIS Having been sworn, testified as follows:',
#  'PHILLIP LeMARQUE Having been sworn, testified as follows:',
#  'PHILLIP W. ESPLIN Having been sworn, testified as follows:',
#  'PRUDENCE BRANDO Having been sworn, testified as follows:',
#  'RALPH CHACON Having been sworn, testified as follows:',
#  'RAMON VELASCO Having been sworn, testified as follows:',
#  'RECROSS-EXAMINATION BY MR. AUCHINCLOSS:',
#  'RECROSS-EXAMINATION BY MR. MESEREAU:',
#  'RECROSS-EXAMINATION BY MR. SANGER:',
#  'RECROSS-EXAMINATION BY MR. SNEDDON:',
#  'RECROSS-EXAMINATION BY MR. ZONEN:',
#  'RECROSS-EXAMINATION Continued BY MR. AUCHINCLOSS:',
#  'REDIRECT EXAMINATION BY MR. AUCHINCLOSS:',
#  'REDIRECT EXAMINATION BY MR. MESEREAU:',
#  'REDIRECT EXAMINATION BY MR. NICOLA:',
#  'REDIRECT EXAMINATION BY MR. SANGER:',
#  'REDIRECT EXAMINATION BY MR. SNEDDON:',
#  'REDIRECT EXAMINATION BY MR. ZONEN:',
#  'RIJO VALDES JACKSON Having been sworn, testified as follows:',
#  'ROBERT CHARLES COOLEY Having been sworn, testified as follows:',
#  'ROBERT SPINNER Having been previously sworn, resumed the stand and testified further as follows:',
#  'ROBERT SPINNER Having been sworn, testified as follows:',
#  'ROD FORNEY Having been sworn, testified as follows:',
#  'ROSIBEL FERRUFINO SMITH Having been sworn, testified as follows:',
#  'ROSIBEL SMITH Having been previously sworn, resumed the stand and testified further as follows:',
#  'RUBY WOLFF Having been sworn, testified as follows:',
#  'RUDY R. PROVENCIO Having been previously sworn, resumed the stand and testified further as follows:',
#  'RUDY R. PROVENCIO Having been sworn, testified as follows:',
#  'RUSSELL ROBERT BIRCHIM Having been sworn, testified as follows:',
#  'Recess taken.',
#  'SHANE MERIDITH Having been previously sworn, resumed the stand and testified further as follows:',
#  'SHANE MERIDITH Having been sworn, testified as follows:',
#  "SHAWN O'GRADY Having been sworn, testified as follows:",
#  'SIMONE PECH JACKSON Having been previously sworn, resumed the stand and testified further as follows:',
#  'SIMONE PECH JACKSON Having been sworn, testified as follows:',
#  'STACY BROWN Having been sworn, testified as follows:',
#  'STAN J. KATZ Having been sworn, testified as follows:',
#  'STAR DAVID ARVIZO Having been previously sworn, resumed the stand and testified further as follows:',
#  'STAR DAVID ARVIZO Having been sworn, testified as follows:',
#  'STEPHEN CLEAVES Having been sworn, testified as follows:',
#  'STEVE DANIEL ROBEL Having been sworn, testified as follows:',
#  'STEVE ROBEL Having been previously sworn, resumed the stand and testified further as follows:',
#  'STEVEN MOELLER Having been sworn, testified as follows:',
#  'SULI MCCULLOUGH Having been sworn, testified as follows:',
#  'Santa Maria, California Friday, April 1, 2005 8:30 a.m.',
#  'Santa Maria, California Friday, April 15, 2005 8:30 a.m.',
#  'Santa Maria, California Friday, April 29, 2005 8:30 a.m.',
#  'Santa Maria, California Friday, April 8, 2005 8:30 a.m.',
#  'Santa Maria, California Friday, June 3, 2005 8:30 a.m.',
#  'Santa Maria, California Friday, March 18, 2005 8:30 a.m.',
#  'Santa Maria, California Friday, March 25, 2005 8:30 a.m.',
#  'Santa Maria, California Friday, March 4, 2005 8:52 a.m.',
#  'Santa Maria, California Friday, May 13, 2005 8:30 a.m.',
#  'Santa Maria, California Friday, May 20, 2005 8:30 a.m.',
#  'Santa Maria, California Friday, May 27, 2005 8:36 a.m.',
#  'Santa Maria, California Friday, May 6, 2005 8:30 a.m.',
#  'Santa Maria, California Monday, April 11, 2005 8:30 a.m.',
#  'Santa Maria, California Monday, April 18, 2005 8:30 a.m.',
#  'Santa Maria, California Monday, April 25, 2005 8:30 a.m.',
#  'Santa Maria, California Monday, April 4, 2005 8:30 a.m.',
#  'Santa Maria, California Monday, February 28, 2005 8:30 a.m.',
#  'Santa Maria, California Monday, March 14, 2005 8:30 a.m.',
#  'Santa Maria, California Monday, March 21, 2005 9:13 a.m.',
#  'Santa Maria, California Monday, March 28, 2005 8:30 a.m.',
#  'Santa Maria, California Monday, March 7, 2005 8:30 a.m.',
#  'Santa Maria, California Monday, March 9, 2005',
#  'Santa Maria, California Monday, May 16, 2005 8:30 a.m.',
#  'Santa Maria, California Monday, May 2, 2005 8:30 a.m.',
#  'Santa Maria, California Monday, May 23, 2005 8:30 a.m.',
#  'Santa Maria, California Monday, May 9, 2005 8:30 a.m.',
#  'Santa Maria, California Thursday, April 14, 2005 8:30 a.m.',
#  'Santa Maria, California Thursday, April 21, 2005 8:30 a.m.',
#  'Santa Maria, California Thursday, April 28, 2005 8:38 a.m.',
#  'Santa Maria, California Thursday, April 7, 2005 8:30 a.m.',
#  'Santa Maria, California Thursday, June 2, 2005 8:30 a.m.',
#  'Santa Maria, California Thursday, March 10, 2005 8:35 a.m.',
#  'Santa Maria, California Thursday, March 17, 2005 8:40 a.m.',
#  'Santa Maria, California Thursday, March 24, 2005 8:30 a.m.',
#  'Santa Maria, California Thursday, March 3, 2005 8:30 a.m.',
#  'Santa Maria, California Thursday, May 12, 2005 8:30 a.m.',
#  'Santa Maria, California Thursday, May 19, 2005 8:30 a.m.',
#  'Santa Maria, California Thursday, May 26, 2005 8:30 a.m.',
#  'Santa Maria, California Thursday, May 5, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, April 12, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, April 19, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, April 26, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, April 5, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, March 1, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, March 15, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, March 22, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, March 29, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, March 8, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, May 10, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, May 17, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, May 24, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, May 3, 2005 8:30 a.m.',
#  'Santa Maria, California Tuesday, May 31, 2005 9:15 a.m.',
#  'Santa Maria, California Wednesday, April 13, 2005 8:30 a.m.',
#  'Santa Maria, California Wednesday, April 20, 2005 8:30 a.m.',
#  'Santa Maria, California Wednesday, April 27, 2005 8:30 a.m.',
#  'Santa Maria, California Wednesday, June 1, 2005 8:40 a.m.',
#  'Santa Maria, California Wednesday, March 16, 2005 8:30 a.m.',
#  'Santa Maria, California Wednesday, March 2, 2005 8:30 a.m.',
#  'Santa Maria, California Wednesday, March 23, 2005 8:30 a.m.',
#  'Santa Maria, California Wednesday, March 30, 2005 8:30 a.m.',
#  'Santa Maria, California Wednesday, May 11, 2005 8:30 a.m.',
#  'Santa Maria, California Wednesday, May 18, 2005 8:30 a.m.',
#  'Santa Maria, California Wednesday, May 25, 2005 8:30 a.m.',
#  'Santa Maria, California Wednesday, May 4, 2005 8:30 a.m.',
#  'TERRY FLAA Having been sworn, testified as follows:',
#  'TERRY PAULSEN Having been sworn, testified as follows:',
#  'THERESA MARQUEZ Having been sworn, testified as follows:',
#  'TIFFANY HAYNES Having been sworn, testified as follows:',
#  'TIMOTHY PATRICK ROONEY Having been sworn, testified as follows:',
#  'TIMOTHY ROONEY Having been sworn, testified as follows:',
#  'TIMOTHY SUTCLIFFE Having been previously sworn, resumed the stand and testified further as follows:',
#  'TIMOTHY SUTCLIFFE Having been sworn, testified as follows:',
#  'The following proceedings were held in open court in the presence and hearing of the jury:',
#  'The following proceedings were held in open court in the presence and hearing of the jury: Off-the-record discussion held at counsel table.',
#  'The following proceedings were held in open court outside the presence and hearing of the jury:',
#  'The proceedings adjourned at 11:05 a.m.',
#  'The proceedings adjourned at 11:25 a.m.',
#  'The proceedings adjourned at 11:30 a.m.',
#  'The proceedings adjourned at 12:30 p.m.',
#  'The proceedings adjourned at 12:55 p.m.',
#  'The proceedings adjourned at 1:20 p.m.',
#  'The proceedings adjourned at 1:25 p.m.',
#  'The proceedings adjourned at 1:47 p.m.',
#  'The proceedings adjourned at 1:49 p.m.',
#  'The proceedings adjourned at 2:00 p.m.',
#  'The proceedings adjourned at 2:10 p.m.',
#  'The proceedings adjourned at 2:15 p.m.',
#  'The proceedings adjourned at 2:20 p.m.',
#  'The proceedings adjourned at 2:30 p.m.',
#  'The proceedings adjourned at 2:35 p.m.',
#  'The proceedings adjourned at 2:40 p.m.',
#  'The proceedings adjourned at 2:55 p.m.',
#  'VERNEE WATSON JOHNSON Having been sworn, testified as follows:',
#  'VICTOR ALVAREZ Having been previously sworn, resumed the stand and testified further as follows:',
#  'VICTOR M. ALVAREZ Having been sworn, testified as follows:',
#  'VIOLET GAITAN SILVA Having been sworn, testified as follows:',
#  'VOIR DIRE EXAMINATION BY MR. SANGER:',
#  'WADE J. ROBSON Having been sworn, testified as follows:',
#  'WILLIAM DICKERMAN Having been previously sworn, resumed the stand and testified further as follows:',
#  'WILLIAM DICKERMAN Having so affirmed, testified as follows:',
#  'WILLIAM F. CALDWELL Having been sworn, testified as follows:'}
